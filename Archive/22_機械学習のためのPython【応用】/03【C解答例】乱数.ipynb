# %% [markdown]
# ## randomライブラリ
#
# randomライブラリを利用して色々なことをやってみよう。
#
# まず、忘れずにライブラリのインポートをしよう。

# %%
import random

# %% [markdown]
# ライブラリのインポートが完了したら、例題に取り掛かろう
#
# 【例題】ランダムな数字を出力してみよう。

# %%
# 何度か実行してランダムな値が出力できることを確認しよう。
print(random.random())
print(random.randint(0,5))
print(random.uniform(10,15))
# Out:
# 0.8182219752327132
# 5
# 13.92578624286663

# %% [markdown]
# **解説**
# * 実行するたびにランダムに値を算出している
# * 範囲は関数によって以下のように決まっている
#     * 0≦x<1の実数`x`を出力する関数random()を動かす場合：random.random()
#     * a≦x≦bの整数`x`を出力する関数randint()を動かす場合：random.randint(a,b)
#     * a≦x≦bの実数`x`を出力する関数uniform()を動かす場合：random.uniform(a,b)

# %% [markdown]
# 【例題】適当なリストの中からランダムに要素を取り出してみよう。

# %%
# 何度か実行してランダムに要素を取り出せることを確認しよう。
animals = ["鼠","牛","虎","兎","竜","蛇","馬","羊","猿","鳥","犬","猪"]
print(random.choice(animals))
# Out:
# 鼠

# %% [markdown]
# **解説**
# * 実行するたびにランダムに要素を取り出している
# * リストからランダムに要素を抽出する方法：random.choice(リスト名)
#
# **注意**
# - 関数名の前に書くライブラリ名を忘れないよう気を付けよう。
#
# 【例題】二つの方法を用いてリストを作成する。どちらの方が早いか測定してみよう。

# %%
print(random.randint(6,8))
# Out:
# 6

# %% [markdown]
# 何度か実行して6,7,8が出力するか、またそれ以外のものが出力されないか確認できたら次の章へ進もう。

# %% [markdown]
# ### random関数の偏り
#
# `random.random()`という関数では、乱数によって0.0～1.0までのランダムな値を算出することができる。
#
# これが本当に偏っているのか、乱数を100個生成して検証してみよう。
#
# 【例題】randomで乱数を100個生成し、リスト`valid`に格納しよう。

# %%
import random
valid = []
for i in range(100):
    valid.append(random.random())
print(valid)
# Out:
# [0.7448613074292556, 0.042191790600871526, 0.3070367535634001, 0.8475780245997868, 0.6054310331729514, 0.10685142938387493, 0.16890937308930587, 0.30422078211071013, 0.9068678834939307, 0.3087931835037222, 0.30600829117386164, 0.5076393545523972, 0.5180009981571991, 0.35981738831098353, 0.033544359036822624, 0.44003852294263246, 0.379019082209752, 0.18000373383746515, 0.6514956653480158, 0.15040062364849538, 0.5780472254468731, 0.8535456824775253, 0.34543782155674296, 0.3452098936489265, 0.8439537425527673, 0.5312257912948555, 0.3661700612859332, 0.9313684722724672, 0.13541654037493744, 0.45532624188990334, 0.2678474372938049, 0.13867371863997058, 0.30726535053130255, 0.12906845790176047, 0.7542704616918928, 0.4946494374981636, 0.25336516699172607, 0.021451156794239812, 0.6043763074846497, 0.34460204681737927, 0.23361726070509892, 0.20784689829522296, 0.4236154491388586, 0.5410365055426873, 0.5212093777689355, 0.05527781758164074, 0.2536180644537749, 0.7916398412042481, 0.26391474995003195, 0.10355348526579133, 0.046799971059443335, 0.8627958723857471, 0.7817654977382456, 0.30173771896393353, 0.020338645913417386, 0.29404496168134675, 0.7894100339795418, 0.5994222969044192, 0.9161060901123291, 0.40490702067458473, 0.22130970308096665, 0.23688026814608287, 0.8572880157779755, 0.31497713482209366, 0.3040080583041883, 0.8334536070815208, 0.00105768651526017, 0.9824855815925441, 0.5220431482796186, 0.43711149445540165, 0.02896998990871591, 0.5766741263174783, 0.8054146058868265, 0.1516246246990245, 0.9153221022428369, 0.7001092442612639, 0.2098684807135841, 0.4188742781916327, 0.25107737796209484, 0.05424608129983377, 0.4229169064038033, 0.9173758559107175, 0.15303819617944558, 0.6228343629006491, 0.8491629131373696, 0.0022389544296665953, 0.364951928116931, 0.9915104438376487, 0.5964305825442429, 0.00559221571025037, 0.15773980804359677, 0.5222789676295237, 0.2587800946817642, 0.931295216248743, 0.0187564792482956, 0.8621274831724288, 0.3590357906564928, 0.4253053226931297, 0.31538343854059236, 0.0037682427875177504]

# %%
print(len(valid))
# Out:
# 100

# %% [markdown]
# 【問題】リスト`valid`の中身について、0.5以下の値が何個あるか計測しよう。

# %%
test = []
for r in valid:
    if r <= 0.5:
        test.append(r)
print(test)
# Out:
# [0.042191790600871526, 0.3070367535634001, 0.10685142938387493, 0.16890937308930587, 0.30422078211071013, 0.3087931835037222, 0.30600829117386164, 0.35981738831098353, 0.033544359036822624, 0.44003852294263246, 0.379019082209752, 0.18000373383746515, 0.15040062364849538, 0.34543782155674296, 0.3452098936489265, 0.3661700612859332, 0.13541654037493744, 0.45532624188990334, 0.2678474372938049, 0.13867371863997058, 0.30726535053130255, 0.12906845790176047, 0.4946494374981636, 0.25336516699172607, 0.021451156794239812, 0.34460204681737927, 0.23361726070509892, 0.20784689829522296, 0.4236154491388586, 0.05527781758164074, 0.2536180644537749, 0.26391474995003195, 0.10355348526579133, 0.046799971059443335, 0.30173771896393353, 0.020338645913417386, 0.29404496168134675, 0.40490702067458473, 0.22130970308096665, 0.23688026814608287, 0.31497713482209366, 0.3040080583041883, 0.00105768651526017, 0.43711149445540165, 0.02896998990871591, 0.1516246246990245, 0.2098684807135841, 0.4188742781916327, 0.25107737796209484, 0.05424608129983377, 0.4229169064038033, 0.15303819617944558, 0.0022389544296665953, 0.364951928116931, 0.00559221571025037, 0.15773980804359677, 0.2587800946817642, 0.0187564792482956, 0.3590357906564928, 0.4253053226931297, 0.31538343854059236, 0.0037682427875177504]

# %%
print(len(test))
# Out:
# 62

# %% [markdown]
# どうだろうか？0.5以下の値の数は100個中50個となっただろうか？
#
# 実は乱数は偏りがあるため、必ず50個ぴったりになるとは限らない。

# %% [markdown]
# 【補足】リスト`valid`および`test`を内包表記で書いてみよう

# %%
from random import random
valid = [random() for i in range(100)]
test = [i for i in valid if i <= 0.5]

# %%
print(len(valid))
print(len(test))
# Out:
# 100
# 55

# %% [markdown]
# このように乱数は偏りが発生するが、上手く使えば様々な機能を実装できる。
#
# 乱数の種類も一様乱数、正規乱数などたくさんあるので、興味のある人は自分で試してみよう。
